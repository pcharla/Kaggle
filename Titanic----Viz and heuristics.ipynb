# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train= pd.read_csv('C:\\Users\\pooja\\Desktop\\Kaggle\\Titanic\\train.csv')
test=pd.read_csv('C:\\Users\\pooja\\Desktop\\Kaggle\\Titanic\\test.csv')
eg= pd.read_csv('C:\\Users\\pooja\\Desktop\\Kaggle\\Titanic\\gender_submission.csv')

# %%
# %matplotlib inline

# %%
V1=train.shape
print(train.count())
print (V1)
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# Hyp            891
# Result         891
# Hyp1           891
# Result1        891
# dtype: int64
# (891, 16)

# %%
train['Age'].fillna(train['Age'].mean(), inplace= True)
train['Embarked']= train['Embarked'].fillna('S')
train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       891
# Hyp            891
# Result         891
# Hyp1           891
# Result1        891
# dtype: int64

# %%
train.loc[train['Embarked']=='S','Embarked']= 0
train.loc[train['Embarked']=='C','Embarked']= 1
train.loc[train['Embarked']== 'Q','Embarked']= 2

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
fig= plt.figure(figsize= (10,10))
plt.subplot2grid((2,3),(0,0))
train['Survived'].value_counts(normalize= True).plot(kind='bar',alpha=0.5)
plt.title('Survived and deceased percentages')

plt.subplot2grid((2,3),(0,1))
plt.scatter(train['Survived'],train['Age'], alpha= 0.1)
plt.title('age versus survived')
plt.tight_layout()

plt.subplot2grid((2,3),(0,2))
train['Pclass'].value_counts(normalize= True).plot(kind='bar', alpha=0.5)
plt.title('class')

plt.subplot2grid((2,3),(1,0), colspan= 2)
for x in [1,2,3]:
    train['Age'][train['Pclass']==x].plot(kind='kde')
plt.title('class wrt age')
plt.legend(('1st','2nd','3rd'))

plt.subplot2grid((2,3),(1,2))
train['Embarked'].value_counts(normalize=True).plot(kind='bar', alpha=0.5)
plt.title('Embarked')
# Out:
# Text(0.5,1,'Embarked')

# %%
for x in ['S','C','Q']:
    train['Survived'][train['Embarked']== x].plot(kind='kde', alpha=0.5)
plt.legend(('S','C','Q'))
plt.title('Survived wrt embarked')
# Out:
# Text(0.5,1,'Survived wrt embarked')

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
for x in [1,2,3]:
    train['Survived'][train['Pclass']== x].plot(kind='kde', alpha=0.5)
plt.legend(('one','two','three'))
plt.title('Survived wrt class')
# Out:
# Text(0.5,1,'Survived wrt class')

# %%
fig1 = plt.figure(figsize=(10,10))
plt.subplot2grid((3,4),(0,0))
train['Survived'][train['Sex']== 'male'].value_counts(normalize= True).plot(kind= 'bar', alpha=0.5)
plt.title('Men survived')
plt.subplot2grid((3,4),(0,1))
train['Survived'][train['Sex']== 'female'].value_counts(normalize= True).plot(kind = 'bar',alpha =0.5)
plt.title('Women survived')
plt.subplot2grid((3,4),(0,2))
train['Sex'][train['Survived']== 1].value_counts(normalize= True).plot(kind = 'bar',alpha =0.5)
plt.title('sex wrt survived')
# Out:
# Text(0.5,1,'sex wrt survived')

# %%
fig2= plt.figure(figsize= (10,10))
plt.subplot2grid((3,4),(0,0))
train.Survived[(train.Sex == 'male') & (train.Pclass == 1)].value_counts(normalize= True).plot(kind= 'bar',alpha= 0.5)
plt.title('Rich men survived')

plt.subplot2grid((3,4),(0,1))
train.Survived[(train.Sex == 'male') & (train.Pclass ==3)].value_counts(normalize= True).plot(kind= 'bar', alpha= 0.5)
plt.title('poor men survived')
# Out:
# Text(0.5,1,'poor men survived')

# %%
fig3= plt.figure(figsize= (10,10))
plt.subplot2grid((3,4),(0,0))
train.Survived[(train.Sex == 'female') & (train.Pclass == 1)].value_counts(normalize= True).plot(kind= 'bar',alpha= 0.5)
plt.title('Rich women survived')

plt.subplot2grid((3,4),(0,1))
train.Survived[(train.Sex == 'female') & (train.Pclass ==3)].value_counts(normalize= True).plot(kind= 'bar', alpha= 0.5)
plt.title('poor women survived')
# Out:
# Text(0.5,1,'poor women survived')

# %% [markdown]
# # time to do algorithm

# %%
train['Hyp']=0
train['Result']=0

# %%
train.loc[train.Sex== 'female', 'Hyp'] =1
train.loc[train.Survived == train.Hyp, 'Result']=1

# %%
train['Result'].value_counts(normalize= True)
# Out:
# 1    0.786756
# 0    0.213244
# Name: Result, dtype: float64

# %%
train['Hyp1']=0
train['Result1']=0
train.loc[train.Pclass== 1, 'Hyp1'] =1
train.loc[train.Pclass==2,'Hyp1'] =1
train.loc[train.Survived == train.Hyp1, 'Result1']=1
train['Result1'].value_counts(normalize= True)
# Out:
# 1    0.667789
# 0    0.332211
# Name: Result1, dtype: float64
